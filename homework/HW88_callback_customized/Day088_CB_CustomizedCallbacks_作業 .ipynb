# %% [markdown]
# ## Work
# 1. 請嘗試寫一個 callback 用來記錄各類別在訓練過程中，對驗證集的 True Positive 與 True Negative
#
# ![image.png](attachment:image.png)

# %%
import os
import keras
import tensorflow as tf
from keras.utils import np_utils

# Disable GPU
os.environ["CUDA_VISIBLE_DEVICES"] = ""

# %%
train, test = tf.keras.datasets.cifar10.load_data()

# %%
## 資料前處理
def preproc_x(x, flatten=True):
    x = x / 255.
    if flatten:
        x = x.reshape((len(x), -1))
    return x

def preproc_y(y, num_classes=10):
    if y.shape[-1] == 1:
        y = np_utils.to_categorical(y, num_classes)
    return y

# %%
x_train, y_train = train
x_test, y_test = test

# Preproc the inputs
x_train = preproc_x(x_train)
x_test = preproc_x(x_test)

# Preprc the outputs
y_train = preproc_y(y_train)
y_test = preproc_y(y_test)

# %%
from keras.layers import BatchNormalization
def build_mlp(input_shape, output_units=10, num_neurons=[256, 256, 256]):
    """Code Here
    建立你的神經網路
    """
    input_layer = keras.layers.Input(input_shape)
    
    for i, n_units in enumerate(num_neurons):
        if i == 0:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(input_layer)
            x = BatchNormalization()(x)
        else:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(x)
            x = BatchNormalization()(x)
    
    out = keras.layers.Dense(units=output_units, activation="softmax", name="output")(x)
    
    model = keras.models.Model(inputs=[input_layer], outputs=[out])
    return model

# %%
## 超參數設定
LEARNING_RATE = 1e-3
EPOCHS = 25
BATCH_SIZE = 1024
MOMENTUM = 0.95

# %%
# 載入 Callbacks
from keras.callbacks import Callback

# Record_fp_tp
class Record_tp_tn(Callback):
    def __init__(self, val_data=(x_test, y_test)):
        self.validation_data = val_data
        
    def on_train_begin(self, epoch, logs = {}):
        logs = logs or {}
        record_items = ["val_tp", "val_tn"]
        for i in record_items:
            try:
                if i not in self.params['metrics']:
                    self.params['metrics'].append(i)
            except:
                self.params['metrics']=i
    
    def on_epoch_end(self, epoch, logs = {}, thres=0.5):
        logs = logs or {}
        y_true = self.validation_data[1].argmax(axis = 1)
        y_pred = self.model.predict(self.validation_data[0])
        y_pred = (y_pred[:, 1] >= thres) * 1
        
        val_tp = sum(y_true*y_pred)
        val_tn = sum((y_true==0) & (y_pred==0))

        logs["val_tp"] = val_tp
        logs["val_tn"] = val_tn 
    
rec_tptn = Record_tp_tn()

# %%
model = build_mlp(input_shape=x_train.shape[1:])
model.summary()
optimizer = tf.keras.optimizers.SGD(lr=LEARNING_RATE, nesterov=True, momentum=MOMENTUM)
model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)

"""Code Here
將 callbacks 放入模型訓練流程中
"""
model.fit(x_train, y_train, 
          epochs=EPOCHS, 
          batch_size=BATCH_SIZE, 
          validation_data=(x_test, y_test), 
          shuffle=True,
          callbacks=[rec_tptn]
         )

# Collect results
train_loss = model.history.history["loss"]
valid_loss = model.history.history["val_loss"]
train_acc = model.history.history["accuracy"]
valid_acc = model.history.history["val_accuracy"]

"""Code Here
將 tp/tn 從訓練完的模型中取出
"""
valid_tp = model.history.history['val_tp']
valid_tn = model.history.history['val_tn']
# Out:
# Model: "model_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         [(None, 3072)]            0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 256)               786688
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 256)               1024
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               65792
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 256)               65792
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 256)               1024
# _________________________________________________________________
# output (Dense)               (None, 10)                2570
# =================================================================
# Total params: 923,914
# Trainable params: 922,378
# Non-trainable params: 1,536
# _________________________________________________________________
# Epoch 1/25
# 49/49 [==============================] - 3s 52ms/step - loss: 2.2088 - accuracy: 0.2683 - val_loss: 2.1649 - val_accuracy: 0.1608
# Epoch 2/25
# 49/49 [==============================] - 2s 43ms/step - loss: 1.7562 - accuracy: 0.3878 - val_loss: 2.0225 - val_accuracy: 0.2506
# Epoch 3/25
# 49/49 [==============================] - 2s 45ms/step - loss: 1.6344 - accuracy: 0.4296 - val_loss: 1.8601 - val_accuracy: 0.3398
# Epoch 4/25
# 49/49 [==============================] - 2s 50ms/step - loss: 1.5632 - accuracy: 0.4536 - val_loss: 1.7251 - val_accuracy: 0.3984
# Epoch 5/25
# 49/49 [==============================] - 2s 48ms/step - loss: 1.5103 - accuracy: 0.4710 - val_loss: 1.6472 - val_accuracy: 0.4243
# Epoch 6/25
# 49/49 [==============================] - 3s 56ms/step - loss: 1.4656 - accuracy: 0.4885 - val_loss: 1.5929 - val_accuracy: 0.4443
# Epoch 7/25
# 49/49 [==============================] - 3s 71ms/step - loss: 1.4308 - accuracy: 0.5020 - val_loss: 1.5595 - val_accuracy: 0.4532
# Epoch 8/25
# 49/49 [==============================] - 3s 64ms/step - loss: 1.3984 - accuracy: 0.5110 - val_loss: 1.5332 - val_accuracy: 0.4640
# Epoch 9/25
# 49/49 [==============================] - 3s 69ms/step - loss: 1.3701 - accuracy: 0.5212 - val_loss: 1.5106 - val_accuracy: 0.4760
# Epoch 10/25
# 49/49 [==============================] - 3s 57ms/step - loss: 1.3421 - accuracy: 0.5315 - val_loss: 1.5008 - val_accuracy: 0.4747
# Epoch 11/25
# 49/49 [==============================] - 3s 57ms/step - loss: 1.3162 - accuracy: 0.5410 - val_loss: 1.4945 - val_accuracy: 0.4754
# Epoch 12/25
# 49/49 [==============================] - 3s 58ms/step - loss: 1.2920 - accuracy: 0.5499 - val_loss: 1.4828 - val_accuracy: 0.4852
# Epoch 13/25
# 49/49 [==============================] - 3s 58ms/step - loss: 1.2708 - accuracy: 0.5586 - val_loss: 1.4750 - val_accuracy: 0.4821
# Epoch 14/25
# 49/49 [==============================] - 3s 56ms/step - loss: 1.2499 - accuracy: 0.5641 - val_loss: 1.4761 - val_accuracy: 0.4832
# Epoch 15/25
# 49/49 [==============================] - 3s 57ms/step - loss: 1.2294 - accuracy: 0.5745 - val_loss: 1.4636 - val_accuracy: 0.4915
# Epoch 16/25
# 49/49 [==============================] - 3s 59ms/step - loss: 1.2085 - accuracy: 0.5837 - val_loss: 1.4667 - val_accuracy: 0.4849
# Epoch 17/25
# 49/49 [==============================] - 3s 55ms/step - loss: 1.1887 - accuracy: 0.5881 - val_loss: 1.4577 - val_accuracy: 0.4886
# Epoch 18/25
# 49/49 [==============================] - 3s 57ms/step - loss: 1.1699 - accuracy: 0.5961 - val_loss: 1.4474 - val_accuracy: 0.4924
# Epoch 19/25
# 49/49 [==============================] - 3s 59ms/step - loss: 1.1522 - accuracy: 0.6041 - val_loss: 1.4515 - val_accuracy: 0.4911
# Epoch 20/25
# 49/49 [==============================] - 3s 66ms/step - loss: 1.1354 - accuracy: 0.6098 - val_loss: 1.4500 - val_accuracy: 0.4932
# Epoch 21/25
# 49/49 [==============================] - 3s 61ms/step - loss: 1.1154 - accuracy: 0.6170 - val_loss: 1.4475 - val_accuracy: 0.4930
# Epoch 22/25
# 49/49 [==============================] - 3s 56ms/step - loss: 1.1005 - accuracy: 0.6230 - val_loss: 1.4561 - val_accuracy: 0.4917
# Epoch 23/25
# 49/49 [==============================] - 3s 55ms/step - loss: 1.0818 - accuracy: 0.6287 - val_loss: 1.4417 - val_accuracy: 0.4974
# Epoch 24/25
# 49/49 [==============================] - 3s 57ms/step - loss: 1.0650 - accuracy: 0.6351 - val_loss: 1.4421 - val_accuracy: 0.4918
# Epoch 25/25
# 49/49 [==============================] - 3s 55ms/step - loss: 1.0489 - accuracy: 0.6417 - val_loss: 1.4521 - val_accuracy: 0.4935

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(range(len(train_loss)), train_loss, label="train loss")
plt.plot(range(len(valid_loss)), valid_loss, label="valid loss")
plt.legend()
plt.title("Loss")
plt.show()

plt.plot(range(len(train_acc)), train_acc, label="train accuracy")
plt.plot(range(len(valid_acc)), valid_acc, label="valid accuracy")
plt.legend()
plt.title("Accuracy")
plt.show()

plt.plot(range(len(valid_tp)), valid_tp, label="valid tp", color="navy")
plt.plot(range(len(valid_tn)), valid_tn, label="valid tn", color="red")
plt.legend()
plt.title("True positives and True Negatives")
plt.show()
